# %%
import pandas as pd
import numpy as np
import os
csvs = [i for i in os.listdir() if '.csv' in i]
feature_df = pd.DataFrame()
for i in range(len(csvs)):
    temp_df = pd.read_csv(csvs[i])
    col_name = csvs[i].replace('.csv','')
    temp_df['col_name'] = col_name
    feature_df = pd.concat([feature_df, temp_df])

# %%
col_names = feature_df['col_name'].unique().tolist()
feature_df[feature_df['col_name'] == col_names[2]]
# Out:
#   Unnamed: 0  Bucket Range     Records  Records (%)  High Risk Ratio  \
# 0          1  (-inf, 1.00)   2,194,865         9.89            12.12
# 1          2   [1.00, inf)  19,778,556        89.08             6.09
# 2          3       Missing     228,985         1.03            83.56
# 3     Totals                22,202,406       100.00             7.49
#
#    Low Risk Ratio                  WoE         col_name
# 0           87.88  -0.5330559717058005  ACTV_60_DYS_avg
# 1           93.91   0.2211435678226565  ACTV_60_DYS_avg
# 2           16.44   -4.140236066600819  ACTV_60_DYS_avg
# 3           92.51                       ACTV_60_DYS_avg

# %%
col_names
# Out:
# ['ACTV_30_DYS_avg',
#  'ACTV_30_DYS_norm',
#  'ACTV_60_DYS_avg',
#  'ACTV_60_DYS_norm',
#  'ACTV_90_DYS_avg',
#  'ACTV_90_DYS_norm',
#  'ADR_CRDT_VERI_STS_mode',
#  'ARPU_12_avg',
#  'ARPU_12_sum',
#  'ARPU_1_avg',
#  'ARPU_1_sum',
#  'ARPU_3_avg',
#  'ARPU_3_sum',
#  'ARPU_6_avg',
#  'ARPU_6_sum',
#  'BAD_DBT_FLG_mode',
#  'BAR_FLG_M6_N_norm',
#  'BAR_FLG_M6_Y_norm',
#  'BAR_FLG_N_norm',
#  'BAR_FLG_Y_norm',
#  'BILL_AMT_M1_avg',
#  'BILL_OUTSTANDING_M1_avg',
#  'BILL_OUTSTANDING_M1_sum',
#  'BILL_OUTSTANDING_M3_avg',
#  'BILL_OUTSTANDING_M3_sum',
#  'BILL_OUTSTANDING_M6_avg',
#  'BILL_OUTSTANDING_M6_sum',
#  'BILL_RENTALS_M1_avg',
#  'BILL_RENTALS_M2_avg',
#  'BILL_RENTALS_M3_avg',
#  'BILL_RENTALS_M4_avg',
#  'BILL_RENTALS_M5_avg',
#  'BILL_RENTALS_M6_avg',
#  'BILL_USAGE_CHRGS_M1_avg',
#  'BILL_USAGE_CHRGS_M2_avg',
#  'BILL_USAGE_CHRGS_M3_avg',
#  'BILL_USAGE_CHRGS_M4_avg',
#  'BILL_USAGE_CHRGS_M5_avg',
#  'BILL_USAGE_CHRGS_M6_avg',
#  'CC_CARD_FLAG_norm',
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

num = 22202
mu = 0
sigma = 0.8
random.seed(10)
df = pd.DataFrame({'party_id':[i for i in range(num)],
                  'risk_probability': [random.uniform(a = 0, b = 1) for i in range(num)]
                  })
df['high_risk_flag'] = [0 if i<0.50 else 1 for i in df['risk_probability']]
##################### BILL  ##############################
df['BILL_OUTSTANDING_M1_avg'] = 5000*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_AMT_M1_avg'] = 4000*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_RENTALS_M1_avg'] = 700*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_RENTALS_M2_avg'] = 1700*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_RENTALS_M3_avg'] = 1600*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_RENTALS_M4_avg'] = 400*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_RENTALS_M5_avg'] = 350*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_RENTALS_M6_avg'] = 400*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_USAGE_CHRGS_M1_avg'] = 0.02*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_USAGE_CHRGS_M2_avg'] = 0.2*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_USAGE_CHRGS_M3_avg'] = 0.2*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_USAGE_CHRGS_M4_avg'] = 0.15*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_USAGE_CHRGS_M5_avg'] = 1300*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_USAGE_CHRGS_M6_avg'] = 1400*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_OUTSTANDING_M1_sum'] = 5000*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_OUTSTANDING_M3_avg'] = 3500*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_OUTSTANDING_M3_sum'] = 7000*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_OUTSTANDING_M6_avg'] = 3000*(df['risk_probability'] + np.random.normal(mu, sigma, num) )
df['BILL_OUTSTANDING_M6_sum'] = 4000*(df['risk_probability'] + np.random.normal(mu, sigma, num) )

########### ACTV ##############
df['ACTV_30_DYS_avg'] = df['risk_probability'] + np.random.normal(mu, sigma, num)
df['ACTV_60_DYS_avg'] = df['risk_probability'] + np.random.normal(mu, sigma, num)
df['ACTV_90_DYS_avg'] = df['risk_probability'] + np.random.normal(mu, sigma, num)
df['ACTV_30_DYS_norm'] = 50*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ACTV_60_DYS_norm'] = 100*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ACTV_90_DYS_norm'] = 25*(df['risk_probability'] + np.random.normal(mu, sigma, num))

########### ARPU #################
df['ARPU_12_avg'] = 350*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_1_avg'] = 3000*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_3_avg'] = 150*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_6_avg'] = 2000*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_12_sum'] = 200*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_1_sum'] = 325*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_3_sum'] = 150*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['ARPU_6_sum'] = 3500*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df
############# FLG ##############
df['BAR_FLG_M6_N_norm'] = 97*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['BAR_FLG_M6_Y_norm'] = 52*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['BAR_FLG_N_norm'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['BAR_FLG_Y_norm'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['CC_CARD_FLG_count']  = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['CST_CAT_FLG_EP_norm'] = 73*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['CST_CAT_FLG_NP_norm'] = 87*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_N_FLG_count'] = 0.5*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_N_FLG_norm'] = 86*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_Other_FLG_count'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_Other_FLG_norm'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_Y_FLG_count'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_Y_FLG_norm'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_N_FLG_count'] = 0.5*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_N_FLG_norm'] = 86*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_Other_FLG_count'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_Other_FLG_norm'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_Y_FLG_count'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_Y_FLG_norm'] = 1*(df['risk_probability'] + np.random.normal(mu, sigma, num))


############## VO #############
df['VO_MOB_MOU_FREE_M1'] = 13500*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['VO_MOB_MOU_OFFNT_M1'] = 3156*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['VO_MOB_MOU_ONNT_M1'] = 15500*(df['risk_probability'] + np.random.normal(mu, sigma, num))

############ PORT #############
df['MNP_PORT_IN_0_count'] = np.random.normal(mu, sigma, num)
df['MNP_PORT_OUT_0_count'] = np.random.normal(mu, sigma, num)
df['MNP_PORT_IN_1_count'] = np.random.normal(mu, sigma, num)
df['MNP_PORT_OUT_1_count'] =np.random.normal(mu, sigma, num)
df['MNP_PORT_IN_0_norm'] = np.random.normal(mu, sigma, num)
df['MNP_PORT_OUT_0_norm'] =np.random.normal(mu, sigma, num)
df['MNP_PORT_IN_1_norm'] = np.random.normal(mu, sigma, num)
df['MNP_PORT_OUT_1_norm'] =np.random.normal(mu, sigma, num)

df['PORTIN_N_FLG_count']=0.5*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_N_FLG_norm']=86*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTIN_Y_FLG_count'] =np.random.normal(mu, sigma, num)
df['PORTIN_Y_FLG_norm']=np.random.normal(mu, sigma, num)
df['PORTIN_Other_FLG_count']=np.random.normal(mu, sigma, num)
df['PORTIN_Other_FLG_norm']=np.random.normal(mu, sigma, num)


df['PORTOUT_N_FLG_count']=0.5*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_N_FLG_norm']=86*(df['risk_probability'] + np.random.normal(mu, sigma, num))
df['PORTOUT_Y_FLG_count'] =np.random.normal(mu, sigma, num)
df['PORTOUT_Y_FLG_norm']=np.random.normal(mu, sigma, num)
df['PORTOUT_Other_FLG_count']=np.random.normal(mu, sigma, num)
df['PORTOUT_Other_FLG_norm']=np.random.normal(mu, sigma, num)
df
# df['PORTIN_Other_FLG_count']
# Out:
#        party_id  risk_probability  high_risk_flag  BILL_OUTSTANDING_M1_avg  \
# 0             0          0.571403               1               268.446372
# 1             1          0.428889               0              1800.409447
# 2             2          0.578091               1              3833.092421
# 3             3          0.206098               0             -4543.636797
# 4             4          0.813321               1              7897.609149
# ...         ...               ...             ...                      ...
# 22197     22197          0.913169               1              5321.444742
# 22198     22198          0.033452               0             -1258.688470
# 22199     22199          0.727680               1             -4665.073735
# 22200     22200          0.934180               1              4038.891802
# 22201     22201          0.413647               0              1986.364146
#
#        BILL_AMT_M1_avg  BILL_RENTALS_M1_avg  BILL_RENTALS_M2_avg  \
# ...

# %%
feature_df[
    (~feature_df.col_name.isin([df.columns])) &
    (feature_df['Bucket Range'].str.contains(', inf')) &
    (feature_df['col_name'].str.contains('PORT')) ]
# Out:
#   Unnamed: 0  Bucket Range     Records  Records (%)  High Risk Ratio  \
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 1          2   [0.50, inf)   1,919,598         8.65             2.47
# 3          4  [86.61, inf)   1,238,946         5.58             0.43
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# 0          1   (-inf, inf)  22,202,406       100.00             7.49
# ...

# %%
import os
import json
import pickle 
import pandas as pd
from datetime import datetime
from pyspark.sql.types import Row
from pyspark.sql.types import MapType
from pyspark.sql.types import ArrayType
from pyspark.sql.types import FloatType
from pyspark.sql.types import StructType
from pyspark.sql.types import StringType
from pyspark.sql.types import DoubleType
from pyspark.sql.types import StructField
from pyspark.sql.types import IntegerType
from pyspark.sql.window import Window
from pyspark.sql.functions import sum
from pyspark.sql.functions import col
from pyspark.sql.functions import udf
from pyspark.sql.functions import lit
from pyspark.sql.functions import lag
from pyspark.sql.functions import asc
from pyspark.sql.functions import max
from pyspark.sql.functions import min
from pyspark.sql.functions import abs
from pyspark.sql.functions import mode
from pyspark.sql.functions import avg
from pyspark.sql.functions import last
from pyspark.sql.functions import expr
from pyspark.sql.functions import desc
from pyspark.sql.functions import year
from pyspark.sql.functions import month
from pyspark.sql.functions import when
from pyspark.sql.functions import lead
from pyspark.sql.functions import count
from pyspark.sql.functions import upper
from pyspark.sql.functions import first
from pyspark.sql.functions import array
from pyspark.sql.functions import length
from pyspark.sql.functions import concat
from pyspark.sql.functions import to_date
from pyspark.sql.functions import datediff
from pyspark.sql.functions import concat_ws
from pyspark.sql.functions import date_format
from pyspark.sql.functions import countDistinct
from pyspark.sql.functions import row_number
from pyspark.sql.functions import collect_list
from pyspark.sql.functions import array_contains
from pyspark.sql.functions import sort_array
from pyspark.sql.functions import collect_set
from pyspark.sql.functions import format_number
from pyspark.sql import functions as F

# %%
analyze_dtypes(df, 'PORTOUT_N_FLG_norm',['party_id'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25548\714101795.py in ?()
# ----> 1 analyze_dtypes(df, 'PORTOUT_N_FLG_norm',['party_id'])
#
# ~\AppData\Local\Temp\ipykernel_25548\3410325668.py in ?(df, target_variable, identity_columns)
#       2 def analyze_dtypes(df, target_variable, identity_columns):
# ----> 3     target_variable_values = [x[target_variable] for x in df.select(target_variable).distinct().collect()]
#       4     if len(target_variable_values)!=2 or 1 not in target_variable_values or 0 not in target_variable_values:
#       5         print("taget variable is not correct format!")
#       6         return False, False, False, False
#
# D:\anaconda3\envs\assetdev\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
# ...

# %%
import pandas as pd
 
# from  pyspark library import 
# SparkSession
from pyspark.sql import SparkSession
 
# Building the SparkSession and name
# it :'pandas to spark'
spark = SparkSession.builder.appName(
  "pandas to spark").getOrCreate()
 
# Create the DataFrame with the help 
# of pd.DataFrame()
data = pd.DataFrame({'State': ['Alaska', 'California',
                               'Florida', 'Washington'],
                      
                     'city': ["Anchorage", "Los Angeles", 
                              "Miami", "Bellevue"]})
 
# create DataFrame
df_spark = spark.createDataFrame(data)
 
df_spark.show()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[201], line 9
#       5 from pyspark.sql import SparkSession
#       7 # Building the SparkSession and name
#       8 # it :'pandas to spark'
# ----> 9 spark = SparkSession.builder.appName(
#      10   "pandas to spark").getOrCreate()
#      12 # Create the DataFrame with the help
#      13 # of pd.DataFrame()
#      14 data = pd.DataFrame({'State': ['Alaska', 'California',
#      15                                'Florida', 'Washington'],
#      16
#      17                      'city': ["Anchorage", "Los Angeles",
#      18                               "Miami", "Bellevue"]})
#
# File D:\anaconda3\envs\assetdev\lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# ...

# %%
variable = 'BILL_OUTSTANDING_M1_avg'
target = 'risk_probability'
x = df[variable].values
y = df[target]
optb = OptimalBinning(name=variable, dtype="numerical", solver="cp")
optb.fit(x, y)
binned_vals = opt.transform(x, metric = 'bins')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[231], line 6
#       4 y = df[target]
#       5 optb = OptimalBinning(name=variable, dtype="numerical", solver="cp")
# ----> 6 optb.fit(x, y)
#       7 binned_vals = opt.transform(x, metric = 'bins')
#
# File D:\anaconda3\envs\assetdev\lib\site-packages\optbinning\binning\binning.py:558, in OptimalBinning.fit(self, x, y, sample_weight, check_input)
#     534 def fit(self, x, y, sample_weight=None, check_input=False):
#     535     """Fit the optimal binning according to the given training data.
#     536
#     537     Parameters
#    (...)
#     556         Fitted optimal binning.
#     557     """
# --> 558     return self._fit(x, y, sample_weight, check_input)
#
# File D:\anaconda3\envs\assetdev\lib\site-packages\optbinning\binning\binning.py:809, in OptimalBinning._fit(self, x, y, sample_weight, check_input)
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
def binner(df, variable, target):
    x = df[variable].values
    y = df[target].values
    optb = OptimalBinning(name=variable, dtype="numerical", solver="cp")
    optb.fit(x, y)
    binned_vals = optb.transform(x, metric = 'bins')
    return binned_vals

cols = df.drop(columns = ['party_id','risk_probability','high_risk_flag']).columns.tolist()
binned_df = df[['party_id','risk_probability','high_risk_flag']]
for col in cols:
    bins = binner(df, col, 'high_risk_flag')
    binned_df[col] = bins
binned_df.head()
# Out:
#    party_id  risk_probability  high_risk_flag BILL_OUTSTANDING_M1_avg  \
# 0         0          0.571403               1       [-437.06, 366.07)
# 1         1          0.428889               0      [1099.01, 2265.87)
# 2         2          0.578091               1      [2848.78, 4362.19)
# 3         3          0.206098               0        (-inf, -4188.24)
# 4         4          0.813321               1      [7263.77, 8560.33)
#
#         BILL_AMT_M1_avg BILL_RENTALS_M1_avg  BILL_RENTALS_M2_avg  \
# 0     [-276.15, 487.55)    [822.37, 939.39)    [-185.39, 116.13)
# 1  [-3577.13, -1880.77)    [-100.02, 85.20)   [2641.32, 3180.55)
# 2    [2811.34, 3332.49)  [-223.77, -100.02)   [1626.10, 2083.59)
# 3    [1878.75, 2353.79)    [-100.02, 85.20)    [-185.39, 116.13)
# 4      (-inf, -3577.13)    [371.27, 475.34)  [-1188.08, -711.99)
#
#   BILL_RENTALS_M3_avg BILL_RENTALS_M4_avg BILL_RENTALS_M5_avg  ...  \
# 0     [81.94, 385.11)      [-8.97, 46.16)       [654.56, inf)  ...
# ...

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = ['party_id','risk_probability','high_risk_flag']), 
                                                    df.high_risk_flag, 
                                                    test_size=0.2, 
                                                    random_state=42)
model = xgb.XGBClassifier(objective='multi:softmax', num_class=3, random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

from sklearn.metrics import classification_report, confusion_matrix

# Calculate precision, recall, F1-score, and support
report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.9043008331456879

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import lightgbm as lgb
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import mlflow 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from datetime import datetime
mlflow.set_experiment(experiment_name=f'experiment_test_'+datetime.now().strftime('%Y_%m_%d_%H_%M_%S'))


# Define classifiers
classifiers = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'XGBoost': xgb.XGBClassifier(objective='binary:logistic', random_state=42),
    'LGBM': lgb.LGBMClassifier()
}

# Define parameter grids for each classifier
param_grids = {
    'Logistic Regression': {'C': [0.01, 0.1, 1, 10, 100]},
    'Decision Tree': {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10]},
    'XGBoost': {'max_depth': [3, 6, 9], 'learning_rate': [0.1, 0.01, 0.001]},
    'LGBM': {'max_depth': [3, 6, 9], 'learning_rate': [0.1, 0.01, 0.001]}
}

# Perform grid search and evaluate each classifier
for classifier_name, classifier in classifiers.items():
    print(f"Running GridSearchCV for {classifier_name}...")
    
    # Perform grid search
    with mlflow.start_run(run_name=classifier_name):
        grid_search = GridSearchCV(classifier, param_grid=param_grids[classifier_name], cv=3, scoring='accuracy')
        grid_search.fit(X_train, y_train)
    
        # Get best parameters and best estimator
        best_params = grid_search.best_params_
        best_estimator = grid_search.best_estimator_
        
        # Make predictions
        y_pred = best_estimator.predict(X_test)
        
        # Evaluate model performance
        accuracy = accuracy_score(y_test, y_pred)
        report = classification_report(y_test, y_pred)
        conf_matrix = confusion_matrix(y_test, y_pred)
        metrics = {
            'accuracy':round(accuracy_score(y_test, y_pred)*100,2),
            'recall':round(recall_score(y_test, y_pred)*100,2),
            'precision':round(precision_score(y_test, y_pred)*100,2),
            'f1_score':round(f1_score(y_test, y_pred)*100,2)
        }
        mlflow.log_metrics(metrics)
# Out:
# 2024/04/15 16:09:12 INFO mlflow.tracking.fluent: Experiment with name 'experiment_test_2024_04_15_16_09_12' does not exist. Creating a new experiment.
# Running GridSearchCV for Logistic Regression...
# Running GridSearchCV for Decision Tree...
# Running GridSearchCV for XGBoost...
# Running GridSearchCV for LGBM...
# [LightGBM] [Info] Number of positive: 5875, number of negative: 5965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003585 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16065
# [LightGBM] [Info] Number of data points in the train set: 11840, number of used features: 63
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.496199 -> initscore=-0.015203
# [LightGBM] [Info] Start training from score -0.015203
# [LightGBM] [Info] Number of positive: 5875, number of negative: 5966
# ...

# %%
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      0.13      0.22      2227\n           1       0.53      1.00      0.69      2214\n\n    accuracy                           0.56      4441\n   macro avg       0.77      0.56      0.46      4441\nweighted avg       0.77      0.56      0.46      4441\n'

# %%
accuracy
# Out:
# 0.5620355775726188

# %%
# Out:
# '2024_04_15_15_46_51'
